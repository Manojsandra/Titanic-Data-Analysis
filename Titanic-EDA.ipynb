# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')
dfc = df
df.drop(columns=["Unnamed: 0"], inplace=True)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dfc.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ##### BASIC STASTISTICAL ANALYSIS

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# #####                             FILLING MISSING VALUES

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# ##### REMOVING UNWANTED COLUMNS

# %%
df = df.drop(columns='Cabin')

# %%
df = df.drop(columns='Ticket')

# %%
df = df.drop(columns='Name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %% [markdown]
# ##### CONVERTING AGE DTYPE FROM FLOAT TO INT

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male   22      1      0   7.2500        S
# 1            2         1       1  female   38      1      0  71.2833        C
# 2            3         1       3  female   26      0      0   7.9250        S
# 3            4         1       1  female   35      1      0  53.1000        S
# 4            5         0       3    male   35      0      0   8.0500        S

# %% [markdown]
# ### EDA(EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ##### UNIVARIATE ANALYSIS FOR NUMERICAL DATA
# Histogram(kde),Boxplot

# %%
df['Age'].skew()
# Out:
# np.float64(0.45956263424701577)

# %%
plt.hist(df['Age'], bins=20,density=True)
sns.kdeplot(df['Age'], color='red')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.boxplot(df['Age'])
plt.title("Age Boxplot")
plt.show()

# %%
plt.hist(df['Fare'],bins=20,density=True)
sns.kdeplot(df['Fare'],color='red')
plt.show()

# %%
plt.boxplot(df['Fare'])
plt.title('fare boxplot')
plt.show()

# %% [markdown]
# ##### UNIVARIATE ANALYSIS FOR CATEGORICAL DATA
# bar chart,pie chart,count plot

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
surv = df['Survived'].value_counts()
surv
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
surv.plot(kind='bar')
plt.title('survived details')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#passenger clause
pclass = df['Pclass'].value_counts()
pclass
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
pclass.plot(kind='bar')
plt.show()

# %%
count = df['Sex'].value_counts()
count
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
count.plot(kind='bar')
plt.show()

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
print(df['Parch'].value_counts())
df['Parch'].value_counts().plot(kind="bar")
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
# <Axes: xlabel='Parch'>

# %% [markdown]
# ##### BIVARIATE ANALYSIS
# scatterplot,heatmap

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male   22      1      0   7.2500        S
# 1            2         1       1  female   38      1      0  71.2833        C
# 2            3         1       3  female   26      0      0   7.9250        S

# %%
survival_rate = df.groupby('Pclass')['Survived']
print(survival_rate.value_counts())
sns.countplot(x='Pclass',hue='Survived',data=df)
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Sex',hue='Survived',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
age_surv = df.groupby('Survived')['Age']
age_surv.value_counts()
# Out:
# Survived  Age
# 0         29     137
#           28      20
#           21      19
#           18      17
#           25      17
#                 ...
# 1         43       1
#           47       1
#           53       1
#           55       1
#           80       1
# Name: count, Length: 124, dtype: int64

# %%
age_surv.mean()
# Out:
# Survived
# 0    30.240437
# 1    28.426901
# Name: Age, dtype: float64

# %%
plt.hist(df['Age'],bins=10,density=True)
sns.kdeplot(df['Age'])
plt.show()

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.kdeplot(data=df, x='Age', hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male   22      1      0   7.2500        S
# 1            2         1       1  female   38      1      0  71.2833        C

# %%
df.groupby('Survived')['SibSp'].value_counts()
# Out:
# Survived  SibSp
# 0         0        398
#           1         97
#           2         15
#           4         15
#           3         12
#           8          7
#           5          5
# 1         0        210
#           1        112
#           2         13
#           3          4
#           4          3
# Name: count, dtype: int64

# %%
sns.countplot(x='SibSp', hue='Survived', data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
print(df.groupby('Survived')['Embarked'].value_counts())
sns.countplot(x='Embarked',hue='Survived',data=df)
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           219
#           C            93
#           Q            30
# Name: count, dtype: int64
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
#bivariate analysis is completed

# %% [markdown]
# ##### converting data from one form to another form
# #1.one-hot encoding

# %%
clean_data = df.head()
clean_data
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male   22      1      0   7.2500        S
# 1            2         1       1  female   38      1      0  71.2833        C
# 2            3         1       3  female   26      0      0   7.9250        S
# 3            4         1       1  female   35      1      0  53.1000        S
# 4            5         0       3    male   35      0      0   8.0500        S

# %%
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare  Sex_male  \
# 0              1         0       3   22      1      0   7.2500      True
# 1              2         1       1   38      1      0  71.2833     False
# 2              3         1       3   26      0      0   7.9250     False
# 3              4         1       1   35      1      0  53.1000     False
# 4              5         0       3   35      0      0   8.0500      True
# ..           ...       ...     ...  ...    ...    ...      ...       ...
# 886          887         0       2   27      0      0  13.0000      True
# 887          888         1       1   19      0      0  30.0000     False
# 888          889         0       3   29      1      2  23.4500     False
# 889          890         1       1   26      0      0  30.0000      True
# 890          891         0       3   32      0      0   7.7500      True
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# ...

# %% [markdown]
# #### MULTIVARIATE ANALYSIS
# corrmatrix(num)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare  Sex_male  \
# 0            1         0       3   22      1      0   7.2500      True
# 1            2         1       1   38      1      0  71.2833     False
# 2            3         1       3   26      0      0   7.9250     False
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
df_corr = df.drop(['Sex_male', 'Embarked_Q', 'Embarked_S'], axis=1)
corr_matrix = df_corr.corr()
plt.figure(figsize=(8,6))

sns.heatmap(corr_matrix,
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Matrix")
plt.show()

# %%
cov_value = df['Pclass'].corr(df['Survived'])
print(cov_value)
# Out:
# -0.3384810359610147

# %%
sns.regplot(x='Fare', y='Survived', data=df)

plt.title("Direction between Pclass and Survival")
plt.xlabel("Fare")
plt.ylabel("Survived")
plt.show()

# %%
"""df['AgeGroup'] = pd.cut(df['Age'],
                     bins=[0, 12, 18, 35, 60, 100],
                       labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])"""

# %%
#df['AgeGroup'] = pd.cut(df['Age'],
                       #bins=[0, 12, 18, 35, 60, 100],
                       #labels=[0, 1, 2, 3, 4])  # numeric labels

# Convert to numeric
#df['AgeGroup'] = df['AgeGroup'].astype(float)

# Regression plot

# %% [markdown]
# #### FEATURE ENGINEERING AND SELECTING

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare  Sex_male  \
# 0            1         0       3   22      1      0   7.2500      True
# 1            2         1       1   38      1      0  71.2833     False
# 2            3         1       3   26      0      0   7.9250     False
# 3            4         1       1   35      1      0  53.1000     False
# 4            5         0       3   35      0      0   8.0500      True
#
#    Embarked_Q  Embarked_S  FamilySize  IsAlone
# 0       False        True           2        0
# 1       False       False           2        0
# 2       False        True           1        1
# 3       False        True           2        0
# 4       False        True           1        1

# %%
df.drop(columns='PassengerId',inplace=True)

# %%
df2 = df
df2
# Out:
#      Survived  Pclass  Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0           0       3   22      1      0   7.2500      True       False
# 1           1       1   38      1      0  71.2833     False       False
# 2           1       3   26      0      0   7.9250     False       False
# 3           1       1   35      1      0  53.1000     False       False
# 4           0       3   35      0      0   8.0500      True       False
# ..        ...     ...  ...    ...    ...      ...       ...         ...
# 886         0       2   27      0      0  13.0000      True       False
# 887         1       1   19      0      0  30.0000     False       False
# 888         0       3   29      1      2  23.4500     False       False
# 889         1       1   26      0      0  30.0000      True       False
# 890         0       3   32      0      0   7.7500      True        True
#
#      Embarked_S  FamilySize  IsAlone
# 0          True           2        0
# ...

# %%
df.drop(columns='SibSp',inplace=True)
df.drop(columns='Parch',inplace=True)

# %%
df.drop(columns='IsAlone',inplace=True)
df
# Out:
#      Survived  Pclass  Age     Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0           0       3   22   7.2500      True       False        True
# 1           1       1   38  71.2833     False       False       False
# 2           1       3   26   7.9250     False       False        True
# 3           1       1   35  53.1000     False       False        True
# 4           0       3   35   8.0500      True       False        True
# ..        ...     ...  ...      ...       ...         ...         ...
# 886         0       2   27  13.0000      True       False        True
# 887         1       1   19  30.0000     False       False        True
# 888         0       3   29  23.4500     False       False        True
# 889         1       1   26  30.0000      True       False       False
# 890         0       3   32   7.7500      True        True       False
#
#      FamilySize
# 0             2
# 1             2
# 2             1
# 3             2
# 4             1
# ..          ...
# ...

# %%
#df3 = df
#df['FamilyGroup'] = pd.cut(df['FamilySize'],bins=[0,1,4,10],labels=['Alone','small','large'])
"""df['FamilyGroup'] = df['FamilyGroup'].str.capitalize()
df['FamilyGroup'] = df['FamilyGroup'].map({
    'Alone': 0,
    'small': 1,
    'Small': 1,
    'Large': 2
})
df['FamilyGroup'] = df['FamilyGroup'].astype(int)"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #df3 = df
#       2 #df['FamilyGroup'] = pd.cut(df['FamilySize'],bins=[0,1,4,10],labels=['Alone','small','large'])
# ----> 3 df['FamilyGroup'] = df['FamilyGroup'].str.capitalize()
#       4 df['FamilyGroup'] = df['FamilyGroup'].map({
#       5     'Alone': 0,
#       6     'small': 1,
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#      Survived  Pclass  Age     Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0           0       3   22   7.2500      True       False        True
# 1           1       1   38  71.2833     False       False       False
# 2           1       3   26   7.9250     False       False        True
# 3           1       1   35  53.1000     False       False        True
# 4           0       3   35   8.0500      True       False        True
# ..        ...     ...  ...      ...       ...         ...         ...
# 886         0       2   27  13.0000      True       False        True
# 887         1       1   19  30.0000     False       False        True
# 888         0       3   29  23.4500     False       False        True
# 889         1       1   26  30.0000      True       False       False
# 890         0       3   32   7.7500      True        True       False
#
#      FamilySize
# 0             2
# 1             2
# 2             1
# 3             2
# 4             1
# ..          ...
# ...

# %%
df[['Sex_male','Embarked_Q','Embarked_S']] = df[['Sex_male','Embarked_Q','Embarked_S']].astype(int)

# %%
df
# Out:
#      Survived  Pclass  Age     Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0           0       3   22   7.2500         1           0           1
# 1           1       1   38  71.2833         0           0           0
# 2           1       3   26   7.9250         0           0           1
# 3           1       1   35  53.1000         0           0           1
# 4           0       3   35   8.0500         1           0           1
# ..        ...     ...  ...      ...       ...         ...         ...
# 886         0       2   27  13.0000         1           0           1
# 887         1       1   19  30.0000         0           0           1
# 888         0       3   29  23.4500         0           0           1
# 889         1       1   26  30.0000         1           0           0
# 890         0       3   32   7.7500         1           1           0
#
#      FamilySize
# 0             2
# 1             2
# 2             1
# 3             2
# 4             1
# ..          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Age         891 non-null    int64
#  3   Fare        891 non-null    float64
#  4   Sex_male    891 non-null    int64
#  5   Embarked_Q  891 non-null    int64
#  6   Embarked_S  891 non-null    int64
#  7   FamilySize  891 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 55.8 KB
